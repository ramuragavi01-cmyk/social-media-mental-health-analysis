# %%
# Project Conclusions
print("""
PROJECT CONCLUSIONS
===================
Dataset: Social Media and Mental Health Survey
Total Respondents: 481
Total Columns: 21

KEY FINDINGS:
1. More females participated in the survey than males.
2. Most respondents are between 18-25 years old.
3. Instagram and YouTube are the most used platforms.
4. People who spend more than 5 hours on social media face highest depression levels.
5. Excessive social media usage negatively impacts concentration ability.
6. People using social media 4+ hours daily face significantly more sleep issues.

OVERALL CONCLUSION:
Excessive social media usage is strongly linked to depression,
poor concentration, and sleep issues among young people.
""")
# Out:
# PROJECT CONCLUSIONS
# ...
# Dataset: Social Media and Mental Health Survey
# Total Respondents: 481
# Total Columns: 21
#
# KEY FINDINGS:
# 1. More females participated in the survey than males.
# 2. Most respondents are between 18-25 years old.
# 3. Instagram and YouTube are the most used platforms.
# 4. People who spend more than 5 hours on social media face highest depression levels.
# 5. Excessive social media usage negatively impacts concentration ability.
# 6. People using social media 4+ hours daily face significantly more sleep issues.
#
# OVERALL CONCLUSION:
# Excessive social media usage is strongly linked to depression,
# poor concentration, and sleep issues among young people.

# %%
# Sleep issues vs time spent on social media
plt.figure(figsize=(10,5))
df.groupby('8. What is the average time you spend on social media every day?')['20. On a scale of 1 to 5, how often do you face issues regarding sleep?'].mean().plot(kind='bar', color='darkblue', edgecolor='black')
plt.title('Sleep Issues vs Time Spent on Social Media')
plt.xlabel('Time Spent on Social Media')
plt.ylabel('Average Sleep Issue Level (1-5)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Average concentration difficulty vs time spent on social media
plt.figure(figsize=(10,5))
df.groupby('8. What is the average time you spend on social media every day?')['14. Do you find it difficult to concentrate on things?'].mean().plot(kind='bar', color='green', edgecolor='black')
plt.title('Concentration Difficulty vs Time Spent on Social Media')
plt.xlabel('Time Spent on Social Media')
plt.ylabel('Average Concentration Difficulty (1-5)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Print all column names clearly
for i, col in enumerate(df.columns):
    print(i, "->", col)
# Out:
# 0 -> Timestamp
# 1 -> 1. What is your age?
# 2 -> 2. Gender
# 3 -> 3. Relationship Status
# 4 -> 4. Occupation Status
# 5 -> 5. What type of organizations are you affiliated with?
# 6 -> 6. Do you use social media?
# 7 -> 7. What social media platforms do you commonly use?
# 8 -> 8. What is the average time you spend on social media every day?
# 9 -> 9. How often do you find yourself using Social media without a specific purpose?
# 10 -> 10. How often do you get distracted by Social media when you are busy doing something?
# 11 -> 11. Do you feel restless if you haven't used Social media in a while?
# 12 -> 12. On a scale of 1 to 5, how easily distracted are you?
# 13 -> 13. On a scale of 1 to 5, how much are you bothered by worries?
# 14 -> 14. Do you find it difficult to concentrate on things?
# 15 -> 15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?
# ...

# %%
# Average depression level by time spent on social media
plt.figure(figsize=(10,5))
df.groupby('8. What is the average time you spend on social media every day?')['18. How often do you feel depressed or down?'].mean().plot(kind='bar', color='steelblue', edgecolor='black')
plt.title('Average Depression Level vs Time Spent on Social Media')
plt.xlabel('Time Spent on Social Media')
plt.ylabel('Average Depression Level (1-5)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# How often do people feel depressed or down?
plt.figure(figsize=(8,4))
df['18. How often do you feel depressed or down?'].value_counts().sort_index().plot(kind='bar', color='tomato', edgecolor='black')
plt.title('How Often People Feel Depressed or Down')
plt.xlabel('Scale (1 = Never, 5 = Always)')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Time spent on social media
plt.figure(figsize=(8,4))
df['8. What is the average time you spend on social media every day?'].value_counts().plot(kind='bar', color='mediumpurple', edgecolor='black')
plt.title('Average Time Spent on Social Media Per Day')
plt.xlabel('Time Spent')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Most used social media platforms
plt.figure(figsize=(10,5))
df['7. What social media platforms do you commonly use?'].value_counts().head(10).plot(kind='bar', color='coral', edgecolor='black')
plt.title('Most Used Social Media Platforms')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Age distribution of respondents
plt.figure(figsize=(8,4))
df['1. What is your age?'].plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution of Respondents')
plt.xlabel('Age')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# How many males and females in the survey?
plt.figure(figsize=(6,4))
df['2. Gender'].value_counts().plot(kind='bar', color=['skyblue', 'pink', 'lightgreen', 'orange'])
plt.title('Gender Distribution of Respondents')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Check missing values
print("Missing Values:")
print(df.isnull().sum())

# Basic statistics
print("\nBasic Statistics:")
df.describe()
# Out:
# Missing Values:
# Timestamp                                                                                                                0
# 1. What is your age?                                                                                                     0
# 2. Gender                                                                                                                0
# 3. Relationship Status                                                                                                   0
# 4. Occupation Status                                                                                                     0
# 5. What type of organizations are you affiliated with?                                                                  30
# 6. Do you use social media?                                                                                              0
# ...

# %%
# Basic information about the data
print("Total Rows and Columns:", df.shape)
print("\nBasic Info:")
df.info()
# Out:
# Total Rows and Columns: (481, 21)
#
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 21 columns):
#  #   Column                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                --------------  -----
#  0   Timestamp                                                                                                             481 non-null    object
#  1   1. What is your age?                                                                                                  481 non-null    float64
#  2   2. Gender                                                                                                             481 non-null    object
# ...

# %%
# How many rows and columns?
print("Shape:", df.shape)

# Column names
print("\nColumn Names:")
for col in df.columns:
    print("-", col)
# Out:
# Shape: (481, 21)
#
# Column Names:
# - Timestamp
# - 1. What is your age?
# - 2. Gender
# - 3. Relationship Status
# - 4. Occupation Status
# - 5. What type of organizations are you affiliated with?
# - 6. Do you use social media?
# - 7. What social media platforms do you commonly use?
# - 8. What is the average time you spend on social media every day?
# - 9. How often do you find yourself using Social media without a specific purpose?
# - 10. How often do you get distracted by Social media when you are busy doing something?
# - 11. Do you feel restless if you haven't used Social media in a while?
# - 12. On a scale of 1 to 5, how easily distracted are you?
# - 13. On a scale of 1 to 5, how much are you bothered by worries?
# - 14. Do you find it difficult to concentrate on things?
# - 15. On a scale of 1-5, how often do you compare yourself to other successful people through the use of social media?
# ...

# %%
# Extract and load the CSV from zip
df = pd.read_csv(zip_file.open('smmh.csv'))

# See the first 5 rows
df.head()
# Out:
#             Timestamp  1. What is your age? 2. Gender 3. Relationship Status  \
# 0  4/18/2022 19:18:47                  21.0      Male      In a relationship
# 1  4/18/2022 19:19:28                  21.0    Female                 Single
# 2  4/18/2022 19:25:59                  21.0    Female                 Single
# 3  4/18/2022 19:29:43                  21.0    Female                 Single
# 4  4/18/2022 19:33:31                  21.0    Female                 Single
#
#   4. Occupation Status 5. What type of organizations are you affiliated with?  \
# 0   University Student                                         University
# 1   University Student                                         University
# 2   University Student                                         University
# 3   University Student                                         University
# 4   University Student                                         University
#
#   6. Do you use social media?  \
# ...

# %%
import zipfile
import io

# Extract the zip file
zip_file = zipfile.ZipFile(io.BytesIO(list(uploaded.values())[0]))

# See what files are inside
print(zip_file.namelist())
# Out:
# ['smmh.csv']

# %%
# Let's check what the file looks like
raw = list(uploaded.values())[0]
print(raw[:500].decode('latin1'))
# Out:
# Ùú7zþ|\~?>ªZ=«WÖûé«zµ=ø¦Gõ×¾­îßÞÝw«\þPoð|<ã#>Ô¿=>©çÎ¿®~êÿ{xËËóêßÿîôét·úúòøõhø¿W÷§§çÇÃÈâoÁ÷û¬þªÛ//O
# Ûútùr|þ¬¾Rß:É}:VjIOO«Ó'ýÕ«ÿë¤r?üæ§ó
# pzPàn¨ZíÂ<ÝôÂÑÕóe%Éê³Â|<<

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fcfbb5f6-4952-4d28-a6bb-e479234b36ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcfbb5f6-4952-4d28-a6bb-e479234b36ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
